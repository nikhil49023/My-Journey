# %% [markdown]
# # 🧪 Practice Lab: Tensors & Data Flow
#
# Welcome to your first coding lab. This notebook is designed to test your intuition about how Tensors work in PyTorch.
#
# ## 🛠️ Setup
# Ensure you are running this in the Learning Lab Docker container.

# %%
import torch
print(f"PyTorch Version: {torch.__version__}")

# %% [markdown]
# ## 🏋️ Problem 1: The Tensor Constructor
# Create a 3x3 tensor called `W` initialized with random values from a normal distribution.
# Then, create a vector `x` of size 3 initialized with ones.

# %%
# YOUR CODE HERE
W = None
x = None

print(f"W: {W}")
print(f"x: {x}")

# %% [markdown]
# ## 🏋️ Problem 2: Matrix Multiplication
# Perform a matrix multiplication between `W` and `x`. Store the result in `y`.
# **Hint:** Use `torch.matmul` or the `@` operator.

# %%
# YOUR CODE HERE
y = None

print(f"y: {y}")

# %% [markdown]
# ## 🏋️ Problem 3: Autograd Logic
# Enable gradient tracking for a new tensor `z = torch.tensor([5.0], requires_grad=True)`.
# Calculate `L = z**3`.
# Run backpropagation and find the gradient `z.grad`.
# What is the mathematical value of the gradient at `z=5`?

# %%
# YOUR CODE HERE
z = None
L = None

print(f"z.grad: {z.grad if z is not None else 'N/A'}")
