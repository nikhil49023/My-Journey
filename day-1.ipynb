# %%
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 54.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 87.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 72.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 90.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([1, 2, 3, 4, 5])
b = np.random.rand(5,6)
print(np.dot(a, b))
plt.bar(a, 6)
# Out:
# [5.16606421 3.87106507 7.10135537 8.47271738 6.78344497 7.48604829]
# <BarContainer object of 5 artists>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print(np.version)
# Out:
# <module 'numpy.version' from '/media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages/numpy/version.py'>
