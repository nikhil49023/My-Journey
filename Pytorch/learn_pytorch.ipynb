# %% [markdown]
# DEEP LEARNING WTH PYTORCH

# %% [markdown]
# Tensors
# are similar to NumPy’s ndarrays, except that tensors can run on GPUs or other hardware accelerators.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !nvidia-smi

# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print(torch.__version__)
# Out:
# 2.11.0+cu130

# %% [markdown]
# Creating Tensors

# %% [markdown]
# using "torch.tensor()"

# %%
scalar = torch.tensor(7)
print("scalar:", scalar)
print("value:", scalar.item())
print("dtype:", scalar.dtype)
print("shape:", scalar.shape)
scalar.ndim #to find number of dimensions
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 scalar = torch.tensor(7, 8)
#       2 scalar
#       3 scalar.ndim #to find number of dimensions
#
# TypeError: tensor() takes 1 positional argument but 2 were given
