# %%
# !pip install torchvision
# !pip install datasets
# Out:
# Requirement already satisfied: torchvision in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (0.26.0)
# Requirement already satisfied: numpy in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torchvision) (2.4.3)
# Requirement already satisfied: torch==2.11.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torchvision) (2.11.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torchvision) (12.1.1)
# Requirement already satisfied: filelock in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (4.15.0)
# Requirement already satisfied: setuptools<82 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (3.6.1)
# Requirement already satisfied: jinja2 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (2026.2.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.11.0->torchvision) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from torch==2.11.0->torchvision) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.11.0->torchvision) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.11.0->torchvision) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.11.0->torchvision) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.11.0->torchvision) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.11.0->torchvision) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.11.0->torchvision) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.11.0->torchvision) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.11.0->torchvision) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.11.0->torchvision) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.11.0->torchvision) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.11.0->torchvision) (13.0.85)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch==2.11.0->torchvision) (1.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch==2.11.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from jinja2->torch==2.11.0->torchvision) (3.0.3)
# Requirement already satisfied: datasets in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (4.8.4)
# Requirement already satisfied: filelock in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (3.25.2)
# Requirement already satisfied: numpy>=1.17 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (2.4.3)
# Requirement already satisfied: pyarrow>=21.0.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (1.8.0)
# Requirement already satisfied: packaging in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.4.2)
# Requirement already satisfied: typer in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from pandas->datasets) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.25.0->datasets) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.25.0->datasets) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /media/nikhil/f470dc98-92e4-4f7d-af60-1bfe0fc74e041/PRO/Learnings.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)

# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import pandas as pd

# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt


training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)
# Out:
# 100%|██████████| 4.42M/4.42M [01:03<00:00, 69.7kB/s]
# 100%|██████████| 5.15k/5.15k [00:01<00:00, 4.91kB/s]

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()
